# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Cargar tu archivo REAL del chat
df = pd.read_csv("df_LimpioFinal.csv")

df
# Out:
#       Rango              Jugador Posición Edad Equipo  Juegos  \
# 0         1   Mahmoud Abdul-Rauf       Pg   28    Sac    31.0
# 1         2             Sin Dato       Sg   23    Sac    59.0
# 2         3  Shareef Abdur-Rahim       Sf   21    Van    82.0
# 3         4       Cory Alexander       Pg   24    Tot    60.0
# 4         4             Sin Dato       Pg   24    Sas    37.0
# ...     ...                  ...      ...  ...    ...     ...
# 18067   152             Rudy Gay       Sf   29    Sac    70.0
# 18068   354             Sin Dato       Sg   29    Bos    42.0
# 18069   186          Josh Howard       Sf   23    Dal    67.0
# 18070   106             Sin Dato        C   23    Orl    77.0
# 18071   176         Fred Hoiberg       Sg   25    Ind    65.0
#
#       Juegos_Iniciados  Minutos_Juego  Tiros_Campo_Anotados  \
# 0                    0           17.1                   3.3
# 1                   16           16.3                   2.4
# ...
